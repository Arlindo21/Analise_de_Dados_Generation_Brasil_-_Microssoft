# %%
pip install rpy2
# %load_ext rpy2.ipython
# Out:
# ERROR:rpy2.situation:Unable to determine R home.
# ERROR:rpy2.situation:Unable to determine R home: [WinError 2] O sistema não conseguiu localizar o ficheiro especificado
# WARNING:root:R_HOME is None.
# WARNING:rpy2.rinterface_lib.openrlib:Error importing in API mode: ImportError('DLL load failed while importing _rinterface_cffi_api: Impossível localizar o módulo especificado.')
# WARNING:rpy2.rinterface_lib.openrlib:Trying to import in ABI mode.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'rpy2.ipython')
#
# File c:\Users\123\AppData\Local\Python\pythoncore-3.14-64\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# ...

# %%
library(ggplot2)#biblioteca para gráficos
install.packages("forecast")#instala a biblioteca forecast
library(forecast)#biblioteca para previsão de séries temporais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 library(ggplot2)#biblioteca para gráficos
#       2 install.packages("forecast")#instala a biblioteca forecast
#       3 library(forecast)#biblioteca para previsão de séries temporais
#
# NameError: name 'library' is not defined
