# %%
#o nosso desafio e mostrar os produtos de um mercado
# Quero poder escolher os produtos , para ver sobre ele
#Adicionar novos produtos
#Poder excluir um produto
# criar as variaveis glbais para o software
Lista_produtos = ['Detergente Ype',
                  'Refrigerante Gengibirra',
                  'Arroz',
                  'Feijão'

]
Lista_Preco=[2.50,5,7.25,4,3.45
]

# %%
#
#
#
def Ver_Produtos():
  print(f'os Produtos que temos são:{Lista_produtos}')
  print(f'os Preços que temos são:  {Lista_Preco}')

def adicionar_produtos():
  novo_produto = input('Informe o nome do produto: ')
  novo_preco = float(input('Informe o preço: '))
  Lista_produtos.append(novo_produto)
  # /\ CHAMAMOS A LISTA - ATRIBUIMOS A FUNÇÃO APPEND (ADICIONA) -
  # COLOCAMOS O QUE VAI SER ADICIONADO
  Lista_preco.append(novo_preco)

# %%
Ver_Produtos()
# Out:
# os Produtos que temos são:['Detergente Ype', 'Refrigerante Gengibirra', 'Arroz', 'Feijão']
# os Preços que temos são:  [2.5, 5, 7.25, 4, 3.45]
