# %%
# usnado sistema de calculadora - CAIXA DE SUPERMERCADO
# quais elementos tem o pagamento?
import numpy as np
# temos produtos
# temos quantidades
# temos um total

  lista_nome = []
  lista_valor = []
  lista_quantidade = []
  while True:

 op_tem = input('Tem algum produto para passar? S/N')
  if op_tem.lower() == 'n':
    print('sistema finalizado')
   break
 elif op_tem.lower() == 's':
    while True:
      # precisamos de variaveis
      # precisamos de listas

      nome = input('Qual o produto?')
      valor = float(input('Quale o valor'))
      quantidade = float(input('Qual a qunatidade'))
      lista_nome.append(nome)
      lista_valor.append(valor)
      lista_quantidade.append(quantidade)

  op_novo_produto= input('Tem algum produto novo para passar? S/N')
  if op_novo_produto.lower() == 'n':
    print('indo para a nota fiscal ')
    print('----- Nota fiscal -----')
    print('Produto | valor | quantidade | total')
    np_valor=np_array(lista_valor)
    np_quantidade=np_array(lista_quantidade)
    total=np.multiply(np_valor,np_quantidade)
    for i,j,k in zip(lista_nome,lista_valor,lista_quantidade,total):
      print(i,j,k,l)
    break
  else:
   print('informe o novo produto')
# Out:
#   File "/tmp/ipykernel_2317/2323505403.py", line 8
#     lista_nome = []
#     ^
# IndentationError: unexpected indent
